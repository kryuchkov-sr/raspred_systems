# %% [markdown]
# **Вывод в консоли результатов отработки server.py и client.py**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image (1).png](data:image/png;base64,...)
